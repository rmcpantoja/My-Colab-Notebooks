# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# install tools
# %cd /content
# !git clone https://github.com/nkreer/sinatoki
# %cd sinatoki
# !git clone https://github.com/lowerquality/gentle
# install sinatoki requirements:
# !apt install php php-cli composer docker.io espeak-ng ffmpeg
# !composer install
# alternative to docker:
# %cd /content/sinatoki/gentle
# !git submodule init
# !git submodule update
# !apt-get update
# !apt-get install -y gcc g++ gfortran libc++-dev libstdc++-6-dev zlib1g-dev automake autoconf libtool git subversion libatlas3-base nvidia-cuda-dev ffmpeg sox
# !apt-get clean
# %cd /content/sinatoki/gentle/ext
# !./install_kaldi.sh
# !make depend
# !make
# !rm -rf kaldi *.o
# %cd /content/sinatoki/gentle
# !python setup.py develop
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#                  1
# ...
# zheequb.f:287:17:
#
#              C0 = -(T*SI)*SI + 2*WORK( I )*SI - N*AVG
#                  1
# ...
# zheequb.f:322:18:
#
#              AVG = AVG + ( U + WORK( I ) ) * D / N
#                   1
# ...
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -msse3 -mssse3 -msse4.1 -mavx -mavx2 -mfma -mavx2  -c -o zlapmr.o zlapmr.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -msse3 -mssse3 -msse4.1 -mavx -mavx2 -mfma -mavx2  -c -o zunbdb.o zunbdb.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -msse3 -mssse3 -msse4.1 -mavx -mavx2 -mfma -mavx2  -c -o zunbdb1.o zunbdb1.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -msse3 -mssse3 -msse4.1 -mavx -mavx2 -mfma -mavx2  -c -o zunbdb2.o zunbdb2.f
# ...

# %%
# %%writefile install_models.sh
# #!/bin/bash
#
# set -e
#
# VERSION="0.03"
#
# download_models() {
# 	local version="$1"
# 	local filename="kaldi-models-$version.zip"
# 	local url="https://lowerquality.com/gentle/$filename"
# 	wget -O $filename $url --no-check-certificate
# 	unzip $filename
# 	rm $filename
# }
#
# echo "Downloading models for v$VERSION..." 1>&2
# download_models $VERSION
# Out:
# Overwriting install_models.sh

# %%
#!./install_models.sh
# %cd /content/sinatoki/gentle
import subprocess
data = subprocess.Popen("python serve.py", shell=True)
print(data)
# Out:
# /content/sinatoki/gentle
# ...

# %%
# !python align.py "/content/drive/MyDrive/us/Oriol/base.mp3" "/content/drive/MyDrive/us/Oriol/Oriol.txt" -o /content/drive/MyDrive/us/Oriol/output.json
# Out:
# INFO:root:converting audio to 8K sampled wav
# INFO:root:starting alignment
# INFO:root:1/53
# INFO:root:2/53
# INFO:root:3/53
# INFO:root:4/53
# INFO:root:5/53
# INFO:root:6/53
# INFO:root:7/53
# INFO:root:8/53
# INFO:root:9/53
# INFO:root:10/53
# INFO:root:11/53
# INFO:root:12/53
# INFO:root:13/53
# INFO:root:14/53
# INFO:root:15/53
# INFO:root:16/53
# INFO:root:17/53
# INFO:root:18/53
# INFO:root:19/53
# INFO:root:20/53
# INFO:root:21/53
# INFO:root:22/53
# INFO:root:23/53
# INFO:root:24/53
# INFO:root:25/53
# INFO:root:26/53
# INFO:root:27/53
# INFO:root:28/53
# INFO:root:29/53
# INFO:root:30/53
# INFO:root:31/53
# INFO:root:32/53
# INFO:root:33/53
# INFO:root:34/53
# INFO:root:35/53
# INFO:root:36/53
# INFO:root:37/53
# INFO:root:38/53
# INFO:root:39/53
# INFO:root:40/53
# INFO:root:41/53
# INFO:root:42/53
# INFO:root:43/53
# INFO:root:44/53
# INFO:root:45/53
# INFO:root:46/53
# INFO:root:47/53
# INFO:root:48/53
# INFO:root:49/53
# INFO:root:50/53
# INFO:root:51/53
# ...

# %%
# %cd /content/sinatoki
# !php sliceAudio.php /content/drive/MyDrive/us/Oriol/output.json /content/drive/MyDrive/us/Oriol/base.mp3 Uriol
# Out:
# /content/sinatoki
# Writing phone map...
# Exporting 140 of words
# Slicing 1 of Vas
# Slicing 2 of jugar
# Slicing 3 of con
# Slicing 1 of número
# Slicing 1 of será
# Slicing 1 of alto
# Slicing 1 of bajo
# Slicing 2 of Esto
# Slicing 2 of un
# Slicing 1 of gol
# Slicing 8 of es
# Slicing 1 of agua
# Slicing 1 of Habrá
# Slicing 2 of que
# Slicing 1 of sancionarlo
# Slicing 2 of el
# Slicing 1 of golpe
# Slicing 1 of redado
# Slicing 1 of la
# Slicing 1 of bota
# Slicing 2 of El
# Slicing 1 of ganador
# Slicing 3 of partido
# Slicing 1 of cero
# Slicing 1 of Uno
# Slicing 1 of uno
# Slicing 1 of Dos
# Slicing 1 of dos
# Slicing 1 of Tres
# Slicing 1 of orgulloso
# Slicing 12 of de
# Slicing 1 of adicción
# Slicing 1 of Has
# Slicing 1 of jugado
# Slicing 1 of muy
# Slicing 2 of mal
# Slicing 1 of Vamos
# Slicing 2 of al
# Slicing 1 of más
# Slicing 1 of fácil
# Slicing 1 of todos
# Slicing 2 of Si
# Slicing 1 of También
# Slicing 1 of puedes
# Slicing 1 of pulsar
# ...

# %%
# synthesis
from IPython.display import Audio, display
# !php synthesizer.php Uriol Welcome.
Audio("/content/sinatoki/output.mp3")
# Out:
# w_ɛ_l_k_ʌ_mAdding w
# Adding eh_l
# Adding k
# Adding ah
# Adding m
# Silence...
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
