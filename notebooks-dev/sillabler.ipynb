# %%
# installation:
# %cd /content
# !git clone https://github.com/gtrabanco/PHP-Syllabler
# %cd PHP-Syllabler
# !apt install php php-cli php-mbstring
# Out:
# /content
# fatal: destination path 'PHP-Syllabler' already exists and is not an empty directory.
# /content/PHP-Syllabler
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# php is already the newest version (1:7.2+60ubuntu1).
# php-cli is already the newest version (1:7.2+60ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   php7.2-mbstring
# The following NEW packages will be installed:
#   php-mbstring php7.2-mbstring
# 0 upgraded, 2 newly installed, 0 to remove and 7 not upgraded.
# Need to get 485 kB of archives.
# After this operation, 1,723 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 php7.2-mbstring amd64 7.2.24-0ubuntu0.18.04.15 [483 kB]
# ...

# %%
# %cd /content/PHP-Syllabler/examples
# !php console.php muchacho
# Out:
# /content/PHP-Syllabler/examples
# PHP Warning:  declare(encoding=...) ignored because Zend multibyte feature is turned off by settings in /content/PHP-Syllabler/library/Fwok/Word/Syllabler/Spanish.php on line 4
# PHP Warning:  declare(encoding=...) ignored because Zend multibyte feature is turned off by settings in /content/PHP-Syllabler/library/Fwok/Word/Syllabler/Abstract.php on line 4
# PHP Warning:  declare(encoding=...) ignored because Zend multibyte feature is turned off by settings in /content/PHP-Syllabler/library/Fwok/Word/Syllabler/Exception.php on line 4
# PHP Warning:  declare(encoding=...) ignored because Zend multibyte feature is turned off by settings in /content/PHP-Syllabler/library/Fwok/Word/Exception.php on line 4
# PHP Warning:  declare(encoding=...) ignored because Zend multibyte feature is turned off by settings in /content/PHP-Syllabler/library/Fwok/Exception.php on line 4
# ...

# %%
# !php html.php
