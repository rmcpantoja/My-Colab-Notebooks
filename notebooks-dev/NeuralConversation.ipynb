# %% [markdown]
# # Bot de conversación neural en español:
#
# Este cuaderno es hecho por [rmcpantoja](https://github.com/rmcpantoja)

# %%
# @markdown # 1: instalar lo necesario
import os
import zipfile
from os.path import exists
if (not os.path.exists("/content/neural-conversation-spanish")):
  print("clonando repositorio...")
  # !git clone https://github.com/eisenjulian/neural-conversation-spanish
if not os.path.exists("/content/es.zip"):
  print("descargando subtítulos... esto puede tomar un tiempo.")
  # !wget http://opus.lingfil.uu.se/download.php?f=OpenSubtitles2016/es.raw.tar.gz -O es.zip
if zipfile.is_zipfile("/content/es.zip"):
  # !unzip -j /content/es.zip -d /content/neural-conversation-spanish/data/subs
else:
  print("Algo falló. Por favor, redescarga los subtítulos e inténtalo nuevamente.")
print("Listo")

# %%
#@markdown #2: Probando
# %cd /content/neural-conversation-spanish
# !python translate.py --decode > ¿Cómo estas? > Bien
